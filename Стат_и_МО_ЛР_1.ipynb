# %% [markdown]
# #  1.1 Вероятностное пространство, формула Байеса

# %% [markdown]
# ## Задание 1

# %% [markdown]
# а) Нет. Возьмем несовместные события A и B. По условию несовместности P(A ∩ B) = 0. Формула пересеченья двух независимых событий P(A ∩ B) = P(A) · P(B). Однако в случае несовместных событий P(A ∩ B) = P(A) · P(B) = 0. Следовательно, несовместные события будут является независимыми тогда и только тогда, когда как минимум одно из них имеет вероятность 0, т.е. невозможно.

# %% [markdown]
# б) Да, если мы рассматриваем 2 события. В этом случае одно из них обязательно представляет из себя само пространство элементарных исходов Ω, P(Ω) = 1, а второе его дополнение пустое множество ∅, P(∅) = 0. Тогда вероятность P(Ω ∩ ∅) = P(Ω) + P(∅) - P(Ω ∪ ∅) = 0 = P(∅) ⋅ P(Ω).
#
# В случае, если событий больше, это неверно. Приведем контрпример. Пусть мы бросаем шестигранный кубик. Составим алгебру логики из следующих событий (элементарные исходы - выпадение одной из цифр от 1 до 6). ∑ = [∅, {1, 3, 5}, {2, 4, 6}, Ω]. Однако P({1, 3, 5}) = P({2, 4, 6}) = 0.5, но при этом P({1, 3, 5} ∩ {2, 4, 6}) = 0 ≠ 0.25, т.к. данные события несовместны.

# %% [markdown]
# с) Нет. Приведем контрпример. Предположим, мы бросаем шестигранный кубик. Вероятность выпадения цифры 3 и 4 равны: P({3}) = P({4}) = 1/6. Однако данные события несовместны и P({3} ∩ {4}) = 0 ≠ 1/36. Аналогично первому примеру, это будет верно тогда и только тогда, когда как минимум одно из них имеет вероятность 0, т.е. невозможно.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# A: {Г, Р}, {Г, Г}
#
# B: {Р, Р}, {Р, Г}
#
# C: {Р, Г}, {Г, Г}
#
# D: {Р, Р}, {Г, Р}
#
# E: {Г, Р}, {Г, Г}, {Р, Г}
#
# F: {Р, Р}, {Р, Г}, {Г, Р}
#
# G: {Р, Г}, {Г, Р}
#
# H: {Р, Р}
#
# K: {Г, Г}

# %% [markdown]
# а) A + C = E. (Появление герба на первой монете или появление герба на второй монете дает множество исходов {Г, Р}, {Г, Г}, {Р, Г}, что равносильно событию появления хотя бы одного герба).
#
# б) AC = K. (Появление герба на первой монете и появление герба на второй монете дает множество исходов {Г, Г}, что равносильно событию появления 2 гербов).
#
# c) EF = G. (Появление хотя бы одного герба и появление хотя бы одной решки дает множество исходов {Г, Р}, {Р, Г}, что равносильно событию одного герба и одной решки)
#
# d) G + E = E. (Появление хотя бы одного герба или появление одного герба и одной решки дает множество исходов {Г, Р}, {Г, Г}, {Р, Г}, что равносильно событию появления хотя бы одного герба)
#
# e) GE = G. (Появление хотя бы одного герба и появление одного герба и одной решки дает множество исходов {Г, Р}, {Р, Г}, что равносильно событию появления одного герба и одной решки)
#
# f) BD = H (Появление решки на первой монете и появление решки на второй монете дает множество исходов {Р, Р}, что равносильно событию непоявления ни одного герба)
#
# g) E + K = E. (Появление хотя бы одного герба или появление двух гербов дает множество исходов {Г, Р}, {Г, Г}, {Р, Г}, что равносильно событию появления хотя бы одного герба)

# %% [markdown]
# ## Задание 3

# %% [markdown]
# Посчитаем общую площадь двух закрашенных секторов мишени:
#
# $S_{закр} = 2 * \frac{α * π * r^2}{360}$ = $\frac{π * r^2}{9}$
#
# Площадь всей мишени:
#
# $S = \pi * r^2$
#
# Тогда вероятность события A попадания в закрашенную область:
#
# $P(A) = \frac{S_{закр}}{S} =  \frac{\frac{π * r^2}{9}}{\pi * r^2} = \frac{1}{9} \approx 0.111$

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Пусть первый пароход прибыл в моменты времени x, второй - в момент времени y (время измеряется в часах, x, y $∈$ [0, 24)).
#
# Второму пароходу придется ждать, если он прибыл в течении часа после прибытия первого, т.е. $x < y < x + 1$. Аналогично, первому пароходу придется ждать, если $y < x < y + 2$.
#
# При построении на графике данные области не пересекаются. Исходя из графика, можем вычислить искомую вероятность как отношение площади, заданную соответствующими двумя уравнениями, к общей площади квадрата ограниченного уравнениями $0 <= x <= 24, 0 <= y<= 24$.
#
# $S_{искомое} = 24*24 - \frac{23*23}{2} - \frac{22*22}{2} = 69.5$
#
# $S_{общая} = 24*24 = 576$
#
# $P_{искомое} = \frac{S_{искомое}}{S_{общая}} \approx 0.121$

# %% [markdown]
# ## Задание 5

# %% [markdown]
# **m = 1**. В данном случае поражение самолета возможно только при попадании в первую часть. Тогда:
#
# $P(A|1) = p_1$

# %% [markdown]
# **m = 2**. В данном случае поражение самолета возможно при попадании хотя бы одного снаряда в первую часть $(A_1)$ или попадании обоих снарядов во вторую часть $(A_2)$.
#
# $P(A_1) = 1 - P(¬A_1) = 1 - (1 - p_1)^2 = 2p_1 - p_1^2$
#
# $P(A_2) = p_2^2$
#
# $P(A|2) =p_2^2 + 2p_1 - p_1^2$

# %% [markdown]
# **m = 3**. В данном случае легче рассуждать от обратного: самолет не будет поражен, если в первую часть попало 0 снарядов, во вторую часть 0 или 1 снарядов, а в третью 0, 1 или 2 снарядов. Учитывая, что число попаданий равно 3, возможно только при попадании 0 янарядов в первую часть, 1 снаряда во вторую и 2 снарядов в третью. Посчитаем по вормуле мультимодального распределения:
#
# $P(\neg A) = P(X_1=0, X_2=1, X_3 = 2) = \frac{3!}{0!1!2!}p_1^0 \cdot p_2^1 \cdot p_3^2 = 3p_2p_3^2$
#
# Тогда искомая вероятность $P(A|3) = 1 - P(\neg A) = 1 - 3p_2p_3^2$

# %% [markdown]
# **m = 4**. В данном случае невозможно непоражение самолета, т.к. все четыре снярадя попали в одну из областей. В третью область должно попасть максимум 2 снаряда, во вторую максимум 1, в первую только 0, т.е. максимальная сумма снярадов до поражения равна 3 <= 4. Таким образом, $P(A|4) = 1$

# %% [markdown]
# # 1.2 Случайный вектор и числовые характеристики

# %% [markdown]
# ## Задание 1

# %% [markdown]
# Проверим выполнение двух ограничений на функцию плотности распределения случайного вектора.
#
# 1) $f_{\epsilon}(x, y) = \frac{e^{(-2|y|)}}{\pi(1 + x^2)} > 0$.
#
# 2) $$
# \int^{+∞}_{-\infty}\int^{+∞}_{-\infty}\frac{e^{(-2|y|)}}{\pi(1 + x^2)}dxdy = \frac{1}{\pi}\int^{+∞}_{-\infty}\frac{dx}{(1 + x^2)} \int^{+∞}_{-\infty}e^{(-2|y|)}dy = $$
# $$
# \frac{1}{\pi}\int^{+∞}_{-\infty}\frac{dx}{(1 + x^2)} (\int^{+∞}_{0}e^{(-2y)}dy + \int^{0}_{-\infty}e^{(2y)}dy) = $$
# $$
# \frac{1}{\pi}\int^{+∞}_{-\infty}\frac{dx}{(1 + x^2)} (\frac{1}{2} + \frac{1}{2}) = \frac{1}{\pi}\int^{+∞}_{-\infty}\frac{dx}{(1 + x^2)} = \frac{1}{\pi}\pi = 1.
# $$
#
# Оба условия соблюдаются. Следовательно, данная функция может являться плотностью распределения случайного вектора.

# %% [markdown]
# ## Задание 2

# %% [markdown]
# a) Маргинальные распределения:
#
# $$ P(ξ = -1) = \frac{1}{2}, P(ξ = 1) = \frac{1}{2} $$
#
# $$ P(η = -1) = \frac{11}{24}, P(η = 0) = \frac{1}{4}, P(η = 1) = \frac{7}{24} $$

# %% [markdown]
# b) Математическое ожидание:
#
# $$ E(\xi) = -\frac{1}{2} + \frac{1}{2} = 0, E(\eta) = -\frac{11}{24} + \frac{7}{24} = -\frac{1}{6}$$
#
# $$ E(\xi, \eta) = \{0, -\frac{1}{6}\}$$.
#
# Ковариационная матрица:
#
# $$ E(\xi\eta) = \frac{1}{8} - \frac{7}{24} - \frac{1}{3} = - \frac{1}{2} $$
# $$ E(\xi^2) = \frac{1}{2} + \frac{1}{2} = 1, D(\xi) = 1$$
# $$ E(\eta^2) = \frac{11}{24} + \frac{7}{24} = \frac{3}{4}, D(\eta) = \frac{13}{18} $$
#
# $$ cov(\xi,\eta) = \begin{pmatrix} 1 & -\frac{1}{2} \\ -\frac{1}{2} & \frac{13}{18} \end{pmatrix} $$
#
# Кореляционная матрица:
#
# $$ r_{\xi, \eta} = \frac{cov(\xi, \eta)}{σ\xi \cdot \sigma\eta} $$
#
# $$ r_{\xi, \eta} = \begin{pmatrix} 1 & -\frac{\sqrt{18}}{2\sqrt{13}} \\ -\frac{\sqrt{18}}{2\sqrt{13}} & 1 \end{pmatrix} $$

# %% [markdown]
# c) $\xi$ и $\eta$ не независимы, т.к. $cov(\xi, \eta) = -0.5 \neq 0$. Можно также говорить об умеренной отрицательной кореляции между случайными величинами ($-\frac{\sqrt{18}}{2\sqrt{13}} ≈ -0.588$).

# %% [markdown]
# ## Задание 3

# %% [markdown]
# a) Таблица совместного распределения $\phi_1$ и $\phi_2$.
#
# \begin{array}{|c|c|} \hline
# \text{$ϕ_1/\phi_2$}&\text{0}&\text{1}\\ \hline
# 2&0&\frac{1}{16}\\ \hline
# 3&0&\frac{1}{8}\\ \hline
# 4&0&\frac{3}{16}\\ \hline
# 5&\frac{1}{8}&\frac{1}{8}\\ \hline
# 6&0&\frac{3}{16}\\ \hline
# 7&\frac{1}{8}&0\\ \hline
# 8&0&\frac{1}{16}\\ \hline
# \end{array}

# %% [markdown]
# b) Маргинальные распределения:
#
# $$P(\phi_1 = 2) = \frac{1}{16}, P(\phi_1 = 3) = \frac{1}{8}, P(\phi_1 = 4) = \frac{3}{16}, P(\phi_1 = 5) = \frac{1}{4}, P(\phi_1 = 6) = \frac{3}{16}, P(\phi_1 = 7) = \frac{1}{8}, P(\phi_1 = 8) = \frac{1}{16}$$.
#
# $$P(\phi_2 = 0) = \frac{1}{4}, P(\phi_2 = 1) = \frac{3}{4}$$

# %% [markdown]
# c) Математическое ожидание:
#
# $$E(\phi_1) = 5, E(\phi_2) = \frac{3}{4}$$
# $$ E(\phi_1, \phi_2) = \{5, \frac{3}{4}\}$$.
#
# Ковариационная матрица:
#
# $$E(\phi_1\phi_2) = \frac{7}{2}$$
# $$E(\phi_1^2) = \frac{55}{2}, D(\phi_1) = \frac{5}{2}$$
# $$E(\phi_2^2) = \frac{3}{4}, D(\phi_2) = \frac{3}{16}$$
#
# $$ cov(\phi_1,\phi_2) = \begin{pmatrix} \frac{5}{2} & -\frac{1}{4} \\ -\frac{1}{4} & \frac{3}{16} \end{pmatrix} $$
#
# Кореляционная матрица:
#
# $$ r_{\phi_1, \phi_2} = \frac{cov(\phi_1,\phi_2)}{σ\phi_1 \cdot \sigma\phi_2} $$
#
# $$ r_{\phi_1, \phi_2}  = \begin{pmatrix} 1 & -\frac{\sqrt{2}}{\sqrt{15}} \\ -\frac{\sqrt{2}}{\sqrt{15}} & 1 \end{pmatrix} $$

# %% [markdown]
# c) $\phi_1$ и $\phi_2$ не независимы, т.к. $cov(\phi_1, \phi_2) = -0.25 \neq 0$. Можно также говорить об умеренной отрицательной кореляции между случайными величинами ($-\frac{\sqrt{2}}{\sqrt{15}} ≈ -0.365$).

# %% [markdown]
# ## Задание 4

# %% [markdown]
# Плотность распределения случайной величины $\xi$:
#
# \begin{equation*}
# f_\xi = \begin{cases}
# \frac{1}{2\pi} & x \in [-\pi, \pi] \\
# 0 & x \notin [-\pi, \pi] \\
# \end{cases}
# \end{equation*}

# %% [markdown]
# Косинус и синус являются непрерывными функциями. Для непрерывной функции $g(x)$ от случайной величины $x$ с плотностью $f(x)$ верно, что:
#
# $$
# E(g(x)) = \int^{\infty}_{\infty}g(x)f(x)dx.
# $$
#
# Тогда:
#
# $$
# E(\eta_1) = \int^{\pi}_{-\pi}\frac{cos(x)}{2\pi}dx = \frac{sin(x)}{2\pi}|^{\pi}_{-\pi} = 0.
# $$
#
# $$
# E(\eta_1) = \int^{\pi}_{-\pi}\frac{sin(x)}{2\pi}dx =- \frac{cos(x)}{2\pi}|^{\pi}_{-\pi} = 0.
# $$

# %% [markdown]
# Ковариационная матрица:
#
# $$
# E(\eta_1\eta_2) =  \int^{\pi}_{-\pi}\frac{cos(x)sin(x)}{2\pi}dx = \int^{\pi}_{-\pi}\frac{sin(2x)}{4\pi}dx = -\frac{cos(x)}{8\pi}|^{\pi}_{-\pi} = 0.
# $$.
#
# $$
# E(\eta_1^2) =  \int^{\pi}_{-\pi}\frac{(cos(x))^2}{2\pi}dx = \int^{\pi}_{-\pi}\frac{1 + cos(2x)}{4\pi}dx = \frac{1}{4\pi}(x + \frac{sin(2x)}{2})|^{\pi}_{-\pi} = \frac{1}{2}, D(\eta_1) = \frac{1}{2}.
# $$.
#
# $$
# E(\eta_2^2) =  \int^{\pi}_{-\pi}\frac{(sin(x))^2}{2\pi}dx = \int^{\pi}_{-\pi}\frac{1 - cos(2x)}{4\pi}dx = \frac{1}{4\pi}(x - \frac{sin(2x)}{2})|^{\pi}_{-\pi} = \frac{1}{2}, D(\eta_2) = \frac{1}{2}.
# $$.
#
# $$
# cov(\eta_1, \eta_2) = \begin{pmatrix} \frac{1}{2} & 0 \\ 0 & \frac{1}{2} \end{pmatrix}
# $$

# %% [markdown]
# Кореляционная матрица:
#
# $$
# r_{\eta_1, \eta_2} = \frac{cov(\eta_1, \eta_2)}{\sigma\eta_1\cdot\sigma\eta_2}
# $$
#
#
# $$ r_{\eta_1, \eta_2}  = \begin{pmatrix} 1 & 0 \\ 0 & 1 \end{pmatrix} $$

# %% [markdown]
# Ковариация $\eta_1, \eta_2$ равна 0, однако это не является достаточным аргументов для вывода о независимости случайных величин. Из постановки задачи очевидно, что переменные зависимы. Обоснуем это контрпримером предположению об их независимости.
#
# Представим события $A: \eta_1 > \frac{\sqrt{3}}{2}$ и $B: \eta_2 > \frac{\sqrt{3}}{2}$. Если $\eta_1, \eta_2$ независимы, то $P(AB) = P(A) \cdot P(B).$ Очевидно, что $P(A) > 0$ и $P(B) > 0$.
#
# Однако для $\eta_1 > \frac{\sqrt{3}}{2}, \eta_2 > \frac{\sqrt{3}}{2}$ также долно быть верно равенство $\eta_1^2 + \eta_2^2 = 1$. Однако, $\eta_1^2 + \eta_2^2 ≥ \frac{3}{4} + \frac{3}{4} = \frac{3}{2} > 1$. Отсюда, противоречие. Следовательно, $P(AB) = 0$. Однако тогда $P(AB) \neq P(A) \cdot P(B).$
#
# Следовательно, случайные величины зависимы.
#
# $cov(\eta_1, \eta_2) = 0$, следовательно, случайные величины некореллированы.

# %% [markdown]
# ## Задание 5

# %% [markdown]
# Плотность распределения случайных величин:
#
# \begin{equation*}
# f_\xi = \begin{cases}
# 0 & x < 0 \\
# 2e^{-2x} & x \geq 0 \\
# \end{cases}
# \end{equation*}
#
# \begin{equation*}
# f_\eta = \begin{cases}
# 0 & x ∉ (0, 1) \\
# 1 & x \in [0, 1] \\
# \end{cases}
# \end{equation*}
#
# Плотность распределения их суммы:
#
# $$f_{\xi+\eta}=∫_{ℝ}f_\xi(u)f_\eta(x-u)du$$
#
# Нас интересуют только ненулевые случаи. Тогда:
#
# \begin{cases}
# x \geq 0 \\
# x - 1 ≤ u \le x \\
# \end{cases}
#
# Возможны два случая:
#
# 1. $$x \geq 1$$
#
#
# $$∫_{x-1}^x2e^{-2u}du = \frac{e^2-1}{e^{2x}}$$
#
# 2. $$0 \le x \le 1$$
#
#
# $$∫_{0}^x2e^{-2u}du = \frac{e^{2x} - 1}{e^{2x}}$$
#
# Тогда плотность распределения суммы $\xi$ и $\eta$:
#
# \begin{equation*}
# f_{\xi+\eta} = \begin{cases}
# 0 & x < 0 \\
# \frac{e^{2x} - 1}{e^{2x}} & 0 \le x \le 1 \\
# \frac{e^2-1}{e^{2x}} & x \geq 1 \\
# \end{cases}
# \end{equation*}
